# %% [markdown]
# # Experiment: Understanding Tasks (Localization, Characterization, and Explanation) on Business Process Drift - (Maaradji - Fast)

# %% [markdown]
# ## Lib Imports and configurations

# %%
# %matplotlib notebook
# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2


import sys
import os
import glob
import io

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pm4py
import ruptures as rpt
from ruptures.metrics import precision_recall, meantime
import scipy.stats as ss
from sklearn.model_selection import ParameterGrid

from tqdm.notebook import tqdm_notebook
import time
from matplotlib.backends.backend_pdf import PdfPages
from joblib import Parallel, delayed

sys.path.append("../Codes/")
import TMPD_utils
import TMPD_class

import warnings
warnings.filterwarnings("ignore")

import gc
gc.enable()

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', 150)
# pd.set_option('display.float_format', lambda x: f'{x:,.3f}')
pd.options.display.float_format = '{:.4f}'.format
np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ## Function to run the class TMPD pipeline in parallel

# %%
def run_pipeline_TMPD(kwargs, display=False, return_bool=False):

    try:

        ### Loading event log
        # Extracting event log
        event_log = TMPD_utils.parse_mxml(kwargs['log_path'])

        # This is a specifc step for this event log that separates in different rows the start and end of an activity. As we will only use one timestamp, we are filtering only the row representing the end of an activity.  
        event_log = event_log[event_log.EventType == "complete"]

        # Save original event index
        event_log = event_log.reset_index(names='original_index') 

        # Create an id based on the order of the event in the raw event log
        event_log["Event_order_id"] = event_log.index

        # This is a specifc step for this event log, because it have duplicated case ids. So we create a new case id.
        event_log["Trace_order"] = TMPD_utils.cumulative_counting(event_log["CaseId"])

        # # Add a Start and End actiivities case it doesn't have
        # event_log = TMPD_utils.add_start_end_activities(event_log=event_log, case_id_col="Trace_order", activity_col="Activity", timestamp_col="Timestamp")


        ### Step 1 - Instantiating class and setting event log
        print('step 1')
        # Iniatializing the TMPD_class
        TMPD_instance = TMPD_class.TMPD(scenario='offline')

        # Setting the transition log
        TMPD_instance.set_transition_log(event_log, case_id = kwargs['case_id'], activity_key = kwargs['activity_key']
                                         , timestamp_key = kwargs['timestamp_key'], timestamp_format=kwargs['timestamp_format'], other_columns_keys=kwargs['other_columns_keys'])

        # Executing the transition log
        TMPD_instance.run_transition_log()

        # Showing the transition log created
        # TMPD_instance.get_transition_log().head(15)

        
        ### Step 2 - Window Strategy
        print('step 2')
        # Setting the window strategy parameters
        TMPD_instance.set_windowing_strategy(window_size_mode = kwargs['window_size_mode'], window_size = kwargs['window_size'], window_ref_mode = kwargs['window_ref_mode']
                                                , overlap = kwargs['overlap'], sliding_step = kwargs['sliding_step'])

        # Executing the window strategy indexation
        TMPD_instance.run_windowing_strategy()

        # Showing the windows indexes
        # dict(list(TMPD_instance.get_windowing_strategy().items())[:15])


        ### Step 3 - Process Representation (using Transition Matrix)
        print('step 3')
        # Setting the Transition Matrix (TM) process representation
        TMPD_instance.set_process_representation(threshold_anomaly = kwargs['threshold_anomaly']
                                            , control_flow_features = kwargs['control_flow_features']
                                            , time_features = kwargs['time_features']
                                            , resource_features = kwargs['resource_features']
                                            , data_features = kwargs['data_features'])

        # Executing the process_representation using all dataset just for an example
        # TMPD_instance.run_process_representation(TMPD_instance.transition_log)

        # Showing the process representation created
        # TMPD_instance.get_process_representation().head(15)


        ### Step 4 - Change Representation
        print('step 4')
        # Setting Change Representation
        TMPD_instance.set_change_representation(kwargs['change_features_strategy_dict'])

        # Executing the Change Representation using the window strategy
        TMPD_instance.run_change_representation()

        # Showing the Change Representation created
        # TMPD_instance.get_change_representation().head(15)


        ### Step 5 - Detection Task
        # print('step 5')
        # # Setting Detection Task
        # TMPD_instance.set_detection_task(kwargs['detection_task_strategy_dict'])

        # # Executing the Detection Task
        # TMPD_instance.run_detection_task()

        # # Getting Detection Task Results
        # detection_task_results = TMPD_instance.get_detection_task()


        ### Step 6a - Localization Task
        print('step 6a')
        # Setting Localization Task
        TMPD_instance.set_localization_task(reference_window_index=kwargs['reference_window_index'], detection_window_index=kwargs['detection_window_index']
                                            , pvalue_threshold=kwargs['pvalue_threshold'], effect_prop_threshold=kwargs['effect_prop_threshold'], effect_count_threshold=kwargs['effect_count_threshold'], pseudo_count=kwargs['pseudo_count'])

        # Executing Localization Task
        TMPD_instance.run_localization_task()

        # Showing Localization Task Results
        changed_transitions, change_informations, reference_bpmn_text, detection_bpmn_text = TMPD_instance.get_localization_task(show_localization_dfg=False, show_original_dfg=False, show_original_bpmn=False)

        # Getting the distinct activities in the Localization Result
        localization_distinct_activities = set()
        for key, value in change_informations.items():
            if isinstance(value, list): # Check if the value is a list
                # Skip the list if it contains only "None"
                if len(value) == 1 and value[0] == "None":
                    continue
                for item in value:
                    if isinstance(item, tuple): # If the items are tuples, extend the set with the tuple items
                        localization_distinct_activities.update(item)
                    else: # If the items are not tuples (i.e., strings), add them directly to the set
                        localization_distinct_activities.add(item)
        localization_result = list(localization_distinct_activities)


        ### Step 6b - Characterization Task
        print('step 6b')
        # Setting Characterization Task
        TMPD_instance.set_characterization_task(llm_company = kwargs['llm_company'], llm_model=kwargs['llm_model'], api_key_path=kwargs['api_key_path'], llm_instructions_path=kwargs['llm_instructions_path'])

        # Executing Characterization Task
        TMPD_instance.run_characterization_task()

        # Showing Characterization Task Results
        # change_patterns_llm_classification, change_patterns_llm_response = TMPD_instance.get_characterization_task()

        ### Defining Grounding truth
        change_pattern_ground_truth = kwargs['log_path'].split("\\")[-2]

        change_activities_ground_truth = {
            'cb': {
                'change_pattern_name': 'CB',
                'characterization_activities': ['Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack'],
                'localization_activities': ['Send_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack', 'Assess_eligibility', 'Send_home_insurance_quote']
            },
            'cd': {
                'change_pattern_name': 'CD',
                'characterization_activities': ['Appraise_property', 'Check_credit_history', 'Assess_loan_risk'],
                'localization_activities': ['Assess_loan_risk', 'Appraise_property', 'Assess_eligibility', 'Check_credit_history']
            },
            'cf': {
                'change_pattern_name': 'CF',
                'characterization_activities': ['Send_home_insurance_quote', 'Send_acceptance_pack'],
                'localization_activities': ['Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote', 'Send_acceptance_pack', 'Verify_repayment_agreement']
            },
            'cm': {
                'change_pattern_name': 'CM',
                'characterization_activities': ['Prepare_acceptance_pack'],
                'localization_activities': ['Send_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack', 'Assess_eligibility', 'Send_home_insurance_quote', 'Verify_repayment_agreement']
            },
            'cp': {
                'change_pattern_name': 'CP',
                'characterization_activities': ['Assess_loan_risk', 'Check_credit_history'],
                'localization_activities': ['Assess_loan_risk', 'Check_credit_history', 'Verify_repayment_agreement', 'Approve_application', 'Cancel_application']
            },
            'fr': {
                'change_pattern_name': 'FR',
                'characterization_activities': ['Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack', 'Send_home_insurance_quote'],
                'localization_activities': ['Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote', 'Send_acceptance_pack', 'Verify_repayment_agreement']
            },
            'lp': {
                'change_pattern_name': 'LP',
                'characterization_activities': ['Assess_loan_risk', 'Appraise_property', 'Assess_eligibility', 'Check_credit_history'],
                'localization_activities': ['Assess_loan_risk', 'Appraise_property', 'Assess_eligibility', 'Check_credit_history', 'Reject_application', 'Prepare_acceptance_pack']
            },
            'pl': {
                'change_pattern_name': 'PL',
                'characterization_activities': ['Appraise_property', 'Check_credit_history', 'Assess_loan_risk'],
                'localization_activities': ['Assess_loan_risk', 'Check__application__form_completeness', 'Appraise_property', 'Assess_eligibility', 'Check_credit_history']
            },
            'pm': {
                'change_pattern_name': 'PM',
                'characterization_activities': ['Prepare_acceptance_pack', 'Send_home_insurance_quote'],
                'localization_activities': ['Send_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack', 'Assess_eligibility', 'Send_home_insurance_quote', 'Verify_repayment_agreement']
            },
            're': {
                'change_pattern_name': 'SRE',
                'characterization_activities': ['Assess_eligibility'],
                'localization_activities': ['Assess_eligibility', 'Reject_application', 'Prepare_acceptance_pack', 'Assess_loan_risk', 'Appraise_property']
            },
            'rp': {
                'change_pattern_name': 'RP',
                'characterization_activities': ['Verify_repayment_agreement', 'Replaced_Activity'],
                'localization_activities': ['Cancel_application', 'Send_acceptance_pack', 'Replaced_Activity', 'Approve_application', 'Send_home_insurance_quote', 'Verify_repayment_agreement']
            },
            'sw': {
                'change_pattern_name': 'SW',
                'characterization_activities': ['Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Verify_repayment_agreement'],
                'localization_activities': ['Send_acceptance_pack', 'Cancel_application', 'Check_if_home_insurance_quote_is_requested', 'Approve_application', 'Prepare_acceptance_pack', 'Assess_eligibility', 'Send_home_insurance_quote', 'Verify_repayment_agreement']
            }
        }

        localization_ground_truth = change_activities_ground_truth[change_pattern_ground_truth]['localization_activities']
        characterization_ground_truth = {'concept_drift' : ['Yes'], 'change_pattern' : [change_activities_ground_truth[change_pattern_ground_truth]['change_pattern_name']], 'activities' : change_activities_ground_truth[change_pattern_ground_truth]['characterization_activities']}


        ### Validation metrics
        print('Validation metrics')

        ## Localization
        # Set comparison for 'Activities'
        precision, recall, f1_score = TMPD_utils.list_match_metrics(localization_ground_truth, localization_result)

        localization_task_validation_results = ({
            'localization_activities_precision': precision,
            'localization_activities_recall': recall,
            'localization_activities_f1_score': f1_score
        })

        ## Characterization
        characterization_result = TMPD_instance.get_characterization_task()[0]

        # Initialize a results dictionary
        characterization_task_validation_results = {
            'characterization_concept_drift_match': None,
            'characterization_change_pattern_match_f1_score': None,
            'characterization_change_pattern_match_precision': None,
            'characterization_change_pattern_match_recall': None,
            'characterization_activities_precision': None,
            'characterization_activities_recall': None,
            'characterization_activities_f1_score': None
        }

        # Check matches
        try:
            characterization_task_validation_results['characterization_concept_drift_match'] = TMPD_utils.list_match_metrics(characterization_ground_truth['concept_drift'], characterization_result['concept_drift'])[2]
        except:
            characterization_task_validation_results['characterization_concept_drift_match'] = -1

        try:
            precision, recall, f1_score = TMPD_utils.list_match_metrics(characterization_ground_truth['change_pattern'], characterization_result['change_pattern'])
            characterization_task_validation_results.update({
                'characterization_change_pattern_match_f1_score': f1_score,
                'characterization_change_pattern_match_precision': precision,
                'characterization_change_pattern_match_recall': recall
            })

        except:
            characterization_task_validation_results.update({
                'characterization_change_pattern_match_f1_score': -1,
                'characterization_change_pattern_match_precision': -1,
                'characterization_change_pattern_match_recall': -1
            })

        # Set comparison for 'Activities'
        precision, recall, f1_score = TMPD_utils.list_match_metrics(characterization_ground_truth['activities'], characterization_result['activities'])

        characterization_task_validation_results.update({
            'characterization_activities_precision': precision,
            'characterization_activities_recall': recall,
            'characterization_activities_f1_score': f1_score
        })


        understanding_tasks_results = pd.DataFrame([{**localization_task_validation_results, **characterization_task_validation_results}])

        understanding_tasks_results['localization_activities'] = ', '.join(localization_result) 
        understanding_tasks_results['characterization_change_pattern'] = ', '.join(TMPD_instance.get_characterization_task()[0]['change_pattern'])
        understanding_tasks_results['characterization_activities'] = ', '.join(TMPD_instance.get_characterization_task()[0]['activities']) 
        understanding_tasks_results['localization_changes'] = [TMPD_instance.get_localization_task(show_localization_dfg=False, show_original_dfg=False, show_original_bpmn=False)[1]]
        understanding_tasks_results['reference_bpmn_text'] = TMPD_instance.get_localization_task(show_localization_dfg=False, show_original_dfg=False, show_original_bpmn=False)[2]
        understanding_tasks_results['detection_bpmn_text'] = TMPD_instance.get_localization_task(show_localization_dfg=False, show_original_dfg=False, show_original_bpmn=False)[3]
        understanding_tasks_results['change_patterns_llm_response'] = TMPD_instance.get_characterization_task()[1]
        


        ### Add informations to final result
        print('Adding informations')
        understanding_tasks_results['log_path'] = kwargs['log_path']
        understanding_tasks_results['change_pattern'] = kwargs['log_path'].split("\\")[-2]
        understanding_tasks_results['log_size'] = event_log['Trace_order'].nunique()
        understanding_tasks_results['window_size_mode'] = kwargs['window_size_mode']
        understanding_tasks_results['window_size'] = kwargs['window_size']
        understanding_tasks_results['window_ref_mode'] = kwargs['window_ref_mode']
        understanding_tasks_results['overlap'] = kwargs['overlap']
        understanding_tasks_results['sliding_step'] = kwargs['sliding_step']

        understanding_tasks_results['reference_window_index'] = kwargs['reference_window_index']
        understanding_tasks_results['detection_window_index'] = kwargs['detection_window_index']
        understanding_tasks_results['pvalue_threshold'] = kwargs['pvalue_threshold']
        understanding_tasks_results['effect_prop_threshold'] = kwargs['effect_prop_threshold']
        understanding_tasks_results['effect_count_threshold'] = kwargs['effect_count_threshold']
        understanding_tasks_results['pseudo_count'] = kwargs['pseudo_count']
        understanding_tasks_results['llm_company'] = kwargs['llm_company']
        understanding_tasks_results['llm_model'] = kwargs['llm_model']
        understanding_tasks_results['llm_instructions_path'] = kwargs['llm_instructions_path']

    

    except Exception as e:
        understanding_tasks_results = pd.DataFrame(data={'Error': [e]})
        understanding_tasks_results['log_path'] = kwargs['log_path']
        understanding_tasks_results['change_pattern'] = kwargs['log_path'].split("\\")[-2]
        understanding_tasks_results['log_size'] = event_log['Trace_order'].nunique()
        understanding_tasks_results['window_size_mode'] = kwargs['window_size_mode']
        understanding_tasks_results['window_size'] = kwargs['window_size']
        understanding_tasks_results['window_ref_mode'] = kwargs['window_ref_mode']
        understanding_tasks_results['overlap'] = kwargs['overlap']
        understanding_tasks_results['sliding_step'] = kwargs['sliding_step']

        understanding_tasks_results['reference_window_index'] = kwargs['reference_window_index']
        understanding_tasks_results['detection_window_index'] = kwargs['detection_window_index']
        understanding_tasks_results['pvalue_threshold'] = kwargs['pvalue_threshold']
        understanding_tasks_results['effect_prop_threshold'] = kwargs['effect_prop_threshold']
        understanding_tasks_results['effect_count_threshold'] = kwargs['effect_count_threshold']
        understanding_tasks_results['pseudo_count'] = kwargs['pseudo_count']
        understanding_tasks_results['llm_company'] = kwargs['llm_company']
        understanding_tasks_results['llm_model'] = kwargs['llm_model']
        understanding_tasks_results['llm_instructions_path'] = kwargs['llm_instructions_path']
    
    # Deleting class instance
    try:
        del TMPD_instance
    except:
        pass

    # Returning detection results or save to file
    if return_bool:
        return understanding_tasks_results
    else:
        understanding_tasks_results.to_pickle("Results/Understanding_Business_Process_Drift_Maaradji_Fast_files/"+ str(kwargs['id']) + ".pkl")

# %% [markdown]
# ## Loading Business Process Drift - (Maaradji - Fast) event logs

# %%
# Mapping all event_logs paths
logs_path = glob.glob("../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs/*/*k.*")

# Keepint only the logs with size 10000 and with single change pattern.
change_patterns_excluded = ['IOR', 'IRO', 'OIR', 'ORI', 'RIO', 'ROI']
logs_path = [x for x in logs_path if "10" in x and not any(keyword in x for keyword in change_patterns_excluded)] 

# Showing mapped paths
print("How many logs? ", len(logs_path))
pd.DataFrame(logs_path)
# Out:
# How many logs?  12
#                                                                                  0
# 0   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cb\cb10k.mxml
# 1   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cd\cd10k.mxml
# 2   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cf\cf10k.mxml
# 3   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cm\cm10k.mxml
# 4   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cp\cp10k.mxml
# 5   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\fr\fr10k.MXML
# 6   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\lp\lp10k.mxml
# 7   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\pl\pl10k.mxml
# 8   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\pm\pm10k.mxml
# 9   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\re\re10k.mxml
# 10  ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\rp\rp10k.mxml
# 11  ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\sw\sw10k.mxml

# %% [markdown]
# <!-- ![Alt text](../Images/Concept_drift_firstcycle_steps_eng.png "General steps") -->

# %% [markdown]
# ## Experiment impacts of the parameters

# %% [markdown]
# ### Define the Parameters GridSearch

# %%
# ### Grid Search of parameters
# TMPD_ParameterGrid = ParameterGrid(
#     [{
#         # Step 1 - Instantiating class and setting event log
#         'case_id' : ['Trace_order']
#         , 'activity_key' : ['Activity']
#         , 'timestamp_key' : ['Timestamp']
#         , 'timestamp_format' : [None]
#         , 'other_columns_keys' : [[]]

#         # Step 2 - Setting Window Strategy
#         , 'window_size_mode' : ['Fixed']
#         , 'window_size' : [1000, 2000, 4000]
#         , 'window_ref_mode' : ['Fixed', 'Sliding']
#         , 'overlap' : [True]
#         , 'sliding_step' : [200, 500]

#         # Step 3 - Setting Process Representation (using Transition Matrix)
#         , 'threshold_anomaly': [0]
#         , 'control_flow_features': [{'frequency', 'probability'}]
#         , 'time_features': [{}] #'avg_time':'timestamp', 'time_std':'timestamp'
#         , 'resource_features': [{}]
#         , 'data_features': [{}]

#         # Step 4 - Setting Change Representation
#         , 'change_features_strategy_dict' : [{
#             'delta_matrix_strategy': 
#                 {
#                     'frequency_delta' : {'process_feature':'frequency', 'method':'aggregation', 'agg_function' : 'sum'}
#                     , 'frequency_delta_percentage' : {'process_feature':'frequency', 'method':'percentage'}
#                     , 'prob_freq_delta_weight' : {'process_feature':'probability', 'method':'aggregation_weight', 'agg_function' : 'sum', 'weight_feature' : 'frequency'}
#                 }
#             , 'statistic_test_strategy' : 
#                 {
#                     'frequency_gtest_pvalue' : {'process_feature':'frequency', 'method':'g_test', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
#                     , 'frequency_cramersv' : {'process_feature':'frequency', 'method':'cramers_v', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
#                 }
#         }]
        
#         # Step 5 - Setting Detection Task
#         , 'detection_task_strategy_dict' :  [
#             {
#             'time_series_strategy': 
#                 {
#                     'cpd_frequency_delta3' : {'change_features':['frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3'}
#                     , 'cpd_prob_freq_delta3' : {'change_features':['prob_freq_delta_weight'], 'method':'cpd_pelt', 'smooth' : '3'}
#                     , 'cpd_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'cpd_pelt', 'smooth' : '3'}  
#                 }
#             , 'threshold_strategy' : 
#                 {
#                     'gtest_frequency3' : {'change_features':['frequency_gtest_pvalue'], 'method':'comparison_operator', 'operator' : 'le', 'threshold_value' : '0.025', 'smooth' : '3'}
#                     , 'fixed_frequency_delta_percentage3' : {'change_features':['frequency_delta_percentage'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
#                     , 'fixed_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
#                 }
#             }
#         ]
#         , 'margin_error' : [3]
#     }
#     , {
#         # Step 1 - Instantiating class and setting event log
#         'case_id' : ['Trace_order']
#         , 'activity_key' : ['Activity']
#         , 'timestamp_key' : ['Timestamp']
#         , 'timestamp_format' : [None]
#         , 'other_columns_keys' : [[]]

#         # Step 2 - Setting Window Strategy
#         , 'window_size_mode' : ['Fixed']
#         , 'window_size' : [1000, 2000, 4000]
#         , 'window_ref_mode' : ['Fixed', 'Sliding']
#         , 'overlap' : [False]
#         , 'sliding_step' : [0]

#         # Step 3 - Setting Process Representation (using Transition Matrix)
#         , 'threshold_anomaly': [0]
#         , 'control_flow_features': [{'frequency', 'probability'}]
#         , 'time_features': [{}] #'avg_time':'timestamp', 'time_std':'timestamp'
#         , 'resource_features': [{}]
#         , 'data_features': [{}]

#         # Step 4 - Setting Change Representation
#         , 'change_features_strategy_dict' : [{
#             'delta_matrix_strategy': 
#                 {
#                     'frequency_delta' : {'process_feature':'frequency', 'method':'aggregation', 'agg_function' : 'sum'}
#                     , 'frequency_delta_percentage' : {'process_feature':'frequency', 'method':'percentage'}
#                     , 'prob_freq_delta_weight' : {'process_feature':'probability', 'method':'aggregation_weight', 'agg_function' : 'sum', 'weight_feature' : 'frequency'}
#                 }
#             , 'statistic_test_strategy' : 
#                 {
#                     'frequency_gtest_pvalue' : {'process_feature':'frequency', 'method':'g_test', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
#                     , 'frequency_cramersv' : {'process_feature':'frequency', 'method':'cramers_v', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
#                 }
#         }]
        
#         # Step 5 - Setting Detection Task
#         , 'detection_task_strategy_dict' :  [
#             {
#             'time_series_strategy': 
#                 {
#                     'cpd_frequency_delta3' : {'change_features':['frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3'}
#                     , 'cpd_prob_freq_delta3' : {'change_features':['prob_freq_delta_weight'], 'method':'cpd_pelt', 'smooth' : '3'}
#                     , 'cpd_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'cpd_pelt', 'smooth' : '3'} 
#                 }
#             , 'threshold_strategy' : 
#                 {
#                     'gtest_frequency3' : {'change_features':['frequency_gtest_pvalue'], 'method':'comparison_operator', 'operator' : 'le', 'threshold_value' : '0.025', 'smooth' : '3'}
#                     , 'fixed_frequency_delta_percentage3' : {'change_features':['frequency_delta_percentage'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
#                     , 'fixed_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
#                 }
#             }
#         ]
#         , 'margin_error' : [3]
#     }
# ])

# %% [markdown]
# ### Combine parameters GridSearch with all event logs

# %%
# TMPD_ParameterGrid_logs = []
# id=0
# for param_grid in TMPD_ParameterGrid:
#     for log_path in logs_path:
#         param_grid_aux = param_grid.copy()
#         param_grid_aux['log_path'] = log_path 
#         param_grid_aux['id'] = id
#         TMPD_ParameterGrid_logs.append(param_grid_aux)
#         id = id+1
# len(TMPD_ParameterGrid_logs)

# %% [markdown]
# ### Execute all experiments in parallel

# %%
# # Executing parameter grid in parallel
# Parallel(n_jobs=-1)(delayed(run_pipeline_TMPD)(TMPD_Parameters, display=False, return_bool=False) for TMPD_Parameters in tqdm_notebook(TMPD_ParameterGrid_logs))

# %%
# # Reading all executes
# saved_pkls = glob.glob("Results/Understanding_Business_Process_Drift_Maaradji_Fast_files/*.pkl")
# results = []
# for saved_pkl in saved_pkls:
#     results.append(pd.read_pickle(saved_pkl))
# results_df = pd.concat(results, axis=0, ignore_index=True)
# results_df.to_csv('Results/Business_Process_Drift_Maaradji_Fast_Understanding_Task.csv')

# %% [markdown]
# ### Load results if necessary

# %%
# results_df = pd.read_csv('Results/Business_Process_Drift_Maaradji_Fast_Understanding_Task.csv', index_col=0)

# %% [markdown]
# ### Analyse results

# %%
# results_df.head()

# %%
# params = ['detection_strategy', 'detection_feature', 'window_size_mode', 'window_size', 'window_ref_mode', 'overlap', 'sliding_step', 'margin_error'] #, 'tipo_mudanca'
# validation_metrics = ["f1","delay"]

# results_df_agg = results_df.groupby(params)[validation_metrics].agg(['mean'])
# results_df_agg.columns = results_df_agg.columns.map('_'.join)
# # results_df_agg.sort_values(["f1_mean","delay_mean"], ascending=[False,True], inplace=True)
# # # all_results_grouped.to_excel(OUTPUT_RESULTS + all_results_grouped_'+model+'.xlsx', sheet_name=model)
# results_df_agg.head(200)

# %% [markdown]
# ## Run specific experiment

# %%
TMPD_ParameterGrid_experiment = ParameterGrid(
    [{
        # Step 1 - Instantiating class and setting event log
        'case_id' : ['Trace_order']
        , 'activity_key' : ['Activity']
        , 'timestamp_key' : ['Timestamp']
        , 'timestamp_format' : [None]
        , 'other_columns_keys' : [[]]

        # Step 2 - Setting Window Strategy
        , 'window_size_mode' : ['Fixed']
        , 'window_size' : [4000]
        , 'window_ref_mode' : ['Fixed'] #, 'Sliding'
        , 'overlap' : [True]
        , 'sliding_step' : [200]

        # Step 3 - Setting Process Representation (using Transition Matrix)
        , 'threshold_anomaly': [0.005]
        , 'control_flow_features': [{'frequency', 'probability'}]
        , 'time_features': [{}] #'avg_time':'timestamp', 'time_std':'timestamp'
        , 'resource_features': [{}]
        , 'data_features': [{}]

        # Step 4 - Setting Change Representation
        , 'change_features_strategy_dict' : [{
            'delta_matrix_strategy': 
                {
                    # 'frequency_delta' : {'process_feature':'frequency', 'method':'aggregation', 'agg_function' : 'sum'}
                    # , 'frequency_delta_percentage' : {'process_feature':'frequency', 'method':'percentage'}
                    # , 'prob_freq_delta_weight' : {'process_feature':'probability', 'method':'aggregation_weight', 'agg_function' : 'sum', 'weight_feature' : 'frequency'}
                }
            , 'statistic_test_strategy' : 
                {
                    'frequency_gtest_pvalue' : {'process_feature':'frequency', 'method':'g_test', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
                    # , 'frequency_cramersv' : {'process_feature':'frequency', 'method':'cramers_v', 'contingency_matrix_sum_value' : '5', 'remove_zeros':'True'}
                }
        }]
        
        # Step 5 - Setting Detection Task
        , 'detection_task_strategy_dict' :  [
            {
            'time_series_strategy': 
                {
                    # 'cpd_frequency_delta3' : {'change_features':['frequency_delta'], 'method':'cpd_pelt', 'smooth' : '3'}
                    # , 'cpd_prob_freq_delta3' : {'change_features':['prob_freq_delta_weight'], 'method':'cpd_pelt', 'smooth' : '3'}
                    # , 'cpd_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'cpd_pelt', 'smooth' : '3'}  
                }
            , 'threshold_strategy' : 
                {
                    'gtest_frequency3' : {'change_features':['frequency_gtest_pvalue'], 'method':'comparison_operator', 'operator' : 'le', 'threshold_value' : '0.025', 'smooth' : '3'}
                    # , 'fixed_frequency_delta_percentage3' : {'change_features':['frequency_delta_percentage'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
                    # , 'fixed_cramersv_frequency3' : {'change_features':['frequency_cramersv'], 'method':'comparison_operator', 'operator' : 'ge', 'threshold_value' : '0.05', 'smooth' : '3'}
                }
            }
        ]

        # Step 6a - Localization Task
        , 'reference_window_index': [0]
        , 'detection_window_index': [75]
        , 'pvalue_threshold': [0.05]
        , 'effect_prop_threshold': [0.2]
        , 'effect_count_threshold': [0.02]
        , 'pseudo_count': [5]

        # Step 6b - Characterization Task
        , 'llm_company' : ['openai'] # 'google', 'openai'
        , 'llm_model': ["gpt-4o"] # "gpt-4o", "gemini-pro", "gpt-4-1106-preview", "gpt-3.5-turbo-0125", "gpt-4"
        , 'api_key_path' : ['../Temp/openai_api_key.txt'] # '../Temp/google_api_key.txt', '../Temp/openai_api_key.txt'
        , 'llm_instructions_path': ['../Codes/LLM_Instructions/instructions_v7.yaml']

    }]
)

# %%
TMPD_ParameterGrid_logs_experiment = []
id=0
for param_grid in TMPD_ParameterGrid_experiment:
    for log_path in logs_path:
        param_grid_aux = param_grid.copy()
        param_grid_aux['log_path'] = log_path 
        param_grid_aux['id'] = id
        TMPD_ParameterGrid_logs_experiment.append(param_grid_aux)
        id = id+1
len(TMPD_ParameterGrid_logs_experiment)
# Out:
# 12

# %%
TMPD_logs_results_experiment = Parallel(n_jobs=1)(delayed(run_pipeline_TMPD)(TMPD_Parameters, display=False, return_bool=True) for TMPD_Parameters in tqdm_notebook(TMPD_ParameterGrid_logs_experiment))
TMPD_logs_results_experiment_df = pd.concat(TMPD_logs_results_experiment, axis=0, ignore_index=True)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]
# step 1
# step 2
# step 3
# step 4
# step 6a
# step 6b
# ################################ llm_bpmn_analysis_response #####################################
# ### Analysis of BPMN Diagrams Before and After Concept Drift ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             ->(
#                 'Prepare_acceptance_pack',
#                 'Check_if_home_insurance_quote_is_requested'
#             ),
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Key Differences and Analysis ###
#
# 1. **Structural Changes in Conditional Fragment:**
#    - **Before Drift:**
#      ```
#      ->(
#          'Prepare_acceptance_pack',
#          'Check_if_home_insurance_quote_is_requested',
#          X(
#              'Send_acceptance_pack',
#              'Send_home_insurance_quote'
#          ),
#          'Verify_repayment_agreement',
#          X(
#              ->(
#                  'Cancel_application',
#                  'Loan__application_canceled'
#              ),
#              ->(
#                  'Approve_application',
#                  'Loan__application_approved'
#              )
#          )
#      )
#      ```
#    - **After Drift:**
#      ```
#      ->(
#          ->(
#              'Prepare_acceptance_pack',
#              'Check_if_home_insurance_quote_is_requested'
#          ),
#          X(
#              'Send_acceptance_pack',
#              'Send_home_insurance_quote'
#          ),
#          'Verify_repayment_agreement',
#          X(
#              ->(
#                  'Cancel_application',
#                  'Loan__application_canceled'
#              ),
#              ->(
#                  'Approve_application',
#                  'Loan__application_approved'
#              )
#          )
#      )
#      ```
#
#    - **Analysis:**
#      - The main change is the introduction of an additional sequential fragment around 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested'. This indicates that these two activities are now explicitly grouped together to be executed in sequence before moving on to the conditional fragment involving 'Send_acceptance_pack' and 'Send_home_insurance_quote'.
#      - This change could imply a more structured approach to handling the preparation and checking of the home insurance quote before deciding on sending the acceptance pack or the insurance quote.
#
# 2. **No Changes in Other Fragments:**
#    - The rest of the BPMN diagram remains unchanged, indicating that the primary process flow, parallel activities, and looping constructs have not been altered.
#
# ### Conclusion ###
# The concept drift in the business process is primarily characterized by a structural change within the conditional fragment related to the preparation and checking of the home insurance quote. This change suggests a more explicit and possibly more controlled sequence of activities before making a decision on sending the acceptance pack or the insurance quote. The rest of the process remains consistent, indicating that the core activities and their sequences, parallels, and loops have not been affected by the drift.
# ################################ llm_transition_analysis_response #####################################
# ### Confirming BPMN Diagram Analysis with Detailed Data ###
#
# #### Key Differences and Analysis Confirmation ####
#
# 1. **Structural Changes in Conditional Fragment:**
#    - **Before Drift:**
#      ```
#      ->(
#          'Prepare_acceptance_pack',
#          'Check_if_home_insurance_quote_is_requested',
#          X(
#              'Send_acceptance_pack',
#              'Send_home_insurance_quote'
#          ),
#          'Verify_repayment_agreement',
#          X(
#              ->(
#                  'Cancel_application',
#                  'Loan__application_canceled'
#              ),
#              ->(
#                  'Approve_application',
#                  'Loan__application_approved'
#              )
#          )
#      )
#      ```
#    - **After Drift:**
#      ```
#      ->(
#          ->(
#              'Prepare_acceptance_pack',
#              'Check_if_home_insurance_quote_is_requested'
#          ),
#          X(
#              'Send_acceptance_pack',
#              'Send_home_insurance_quote'
#          ),
#          'Verify_repayment_agreement',
#          X(
#              ->(
#                  'Cancel_application',
#                  'Loan__application_canceled'
#              ),
#              ->(
#                  'Approve_application',
#                  'Loan__application_approved'
#              )
#          )
#      )
#      ```
#
#    - **Analysis Confirmation:**
#      - The detailed data confirms the structural change identified in the BPMN diagrams. The transitions involving 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' are now explicitly grouped together in sequence before moving on to the conditional fragment involving 'Send_acceptance_pack' and 'Send_home_insurance_quote'.
#      - This is supported by the new transitions added to the process: `('Assess_eligibility', 'Send_home_insurance_quote')` and `('Assess_eligibility', 'Send_acceptance_pack')`, which indicate a more structured approach to handling these activities.
#
# 2. **No Changes in Other Fragments:**
#    - The rest of the BPMN diagram remains unchanged, indicating that the primary process flow, parallel activities, and looping constructs have not been altered.
#    - This is confirmed by the detailed data, which shows no new or deleted activities, start activities, or end activities, and no changes in the core transitions outside the identified conditional fragment.
#
# ### Delving Deeper into Discrepancies and Nuances ###
#
# 1. **Changes in Control-Flow:**
#    - The detailed data shows variations in the probability and frequency of transitions involving 'Assess_eligibility', 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack', and 'Send_home_insurance_quote'. This suggests that while the structural change is the most significant, there are also changes in how often and how likely certain transitions are to occur.
#    - Specifically, the transitions `('Assess_eligibility', 'Send_acceptance_pack')` and `('Assess_eligibility', 'Send_home_insurance_quote')` are new, indicating that these paths are now possible directly from 'Assess_eligibility', which was not the case before.
#
# 2. **Movements of Activities within the Process Flow:**
#    - The movement of 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' into a sequential fragment before the conditional fragment is a significant change. This movement ensures that these activities are completed before any decision is made regarding sending the acceptance pack or the home insurance quote.
#
# 3. **Adjustments in Loops:**
#    - There are no explicit loops in the BPMN diagrams provided, and the detailed data does not indicate any changes in looping constructs. The focus remains on the conditional fragment changes.
#
# 4. **Transformations Affecting Skippability of Activities:**
#    - The new transitions `('Assess_eligibility', 'Send_home_insurance_quote')` and `('Assess_eligibility', 'Send_acceptance_pack')` suggest that it is now possible to skip 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' under certain conditions. This was not explicitly captured in the initial BPMN analysis but is evident from the detailed data.
#    - This implies that the activities 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have become skippable, which is a significant transformation in the process flow.
#
# ### Conclusion ###
#
# The detailed data confirms the primary structural change identified in the BPMN diagrams, where 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' are now explicitly grouped together in sequence. Additionally, the data reveals nuances such as changes in transition probabilities and frequencies, and the introduction of new transitions that allow certain activities to be skippable. These findings provide a deeper understanding of the concept drift, highlighting both the structural and probabilistic changes in the business process.
# ################################ characterization_classification #####################################
# ### Step-by-Step Analysis ###
#
# #### Step 1: Confirm Concept Drift ####
# Based on the provided analysis, there is a clear indication of a structural change in the business process. The activities 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have been grouped together in sequence before the conditional fragment. This confirms the presence of concept drift.
#
# #### Step 2: Identify the Change Pattern ####
# Given the structural change, we need to classify the change pattern using the pre-defined patterns:
#
# 1. **Serial Move (SM):**
#    - The activities 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have moved into a sequence.
#    - Evidence: Sequence (->) fragment changed in BPMN diagram comparison.
#    - Both new and deleted transitions involving the moved activities.
#
# 2. **Conditional Move (CM):**
#    - The activities have not moved into a conditional (X) fragment.
#
# 3. **Parallel Move (PM):**
#    - The activities have not moved into a parallel (+) fragment.
#
# 4. **Swap (SW):**
#    - Multiple activities have not swapped positions.
#
# 5. **Parallel (PL):**
#    - No change from sequential to parallel or vice versa.
#
# 6. **Conflict (CF):**
#    - No change from sequential to conditional or vice versa.
#
# 7. **Control Dependency (CD):**
#    - No reordering within a parallel (+) fragment.
#
# 8. **Conditional Branch (CB):**
#    - The new transitions suggest that 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have become skippable.
#    - Evidence: New conditional (X) fragment and new transitions making activities skippable.
#
# 9. **Copy (CP):**
#    - No new or deleted loop fragment with conditional (X) and silent transition ('tau').
#
# 10. **Loop (LP):**
#     - No new or deleted loop fragment.
#
# #### Step 3: Determine the Most Significant Change Pattern ####
# The most significant change pattern is **Conditional Branch (CB)**, as the new transitions `('Assess_eligibility', 'Send_home_insurance_quote')` and `('Assess_eligibility', 'Send_acceptance_pack')` make 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' skippable.
#
# ### Final Conclusion ###
# Based on the analysis, the final conclusion is:
#
# ```python
# ### result_dict = {'concept_drift' : ['Yes'], 'change_pattern' : ['CB'], 'activities' : ['Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested']}
# ```
# ################################ characterization_classification_dict #####################################
# {'concept_drift': ['Yes'], 'change_pattern': ['CB'], 'activities': ['Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested']}
# Validation metrics
# Adding informations
# step 1
# step 2
# step 3
# step 4
# step 6a
# step 6b
# ################################ llm_bpmn_analysis_response #####################################
# ### Analysis of BPMN Diagrams Before and After Concept Drift ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         'Check_credit_history'
#     ),
#     'Assess_loan_risk',
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Identified Changes ###
#
# 1. **Change in Parallel Fragment:**
#    - **Before Drift:** The parallel fragment includes 'Appraise_property' and a nested sequential fragment '->( 'Check_credit_history', 'Assess_loan_risk' )'.
#    - **After Drift:** The parallel fragment includes 'Appraise_property' and 'Check_credit_history' as separate parallel activities. The 'Assess_loan_risk' activity has been moved out of the parallel fragment and placed sequentially after it.
#
# 2. **Change in Sequence:**
#    - **Before Drift:** 'Assess_loan_risk' is part of the nested sequential fragment within the parallel fragment.
#    - **After Drift:** 'Assess_loan_risk' is now a standalone activity that follows the parallel fragment.
#
# ### Summary of Changes ###
#
# - **Parallelism Adjustment:** The 'Check_credit_history' and 'Assess_loan_risk' activities were initially executed in sequence within a parallel fragment. After the drift, 'Check_credit_history' is executed in parallel with 'Appraise_property', and 'Assess_loan_risk' is executed sequentially after the parallel fragment.
# - **Sequential Flow Adjustment:** The movement of 'Assess_loan_risk' from within the parallel fragment to a position after it indicates a change in the control flow, potentially reflecting a reordering of tasks to optimize the process or address a new business requirement.
#
# These changes suggest a significant restructuring of the process flow, likely aimed at improving efficiency or addressing new operational constraints. The movement of 'Assess_loan_risk' out of the parallel fragment and into the main sequential flow could indicate a need to ensure that risk assessment is completed only after both property appraisal and credit history checks are done independently.
# ################################ llm_transition_analysis_response #####################################
# ### Confirming BPMN Diagram Analysis with Detailed Data ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         'Check_credit_history'
#     ),
#     'Assess_loan_risk',
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Detailed Data Analysis ###
#
# #### Transitions with Variations in Probability and Frequency ####
# - **Transitions with variations in probability and frequency:**
#   - ('Appraise_property', 'Assess_eligibility')
#   - ('Appraise_property', 'Assess_loan_risk')
#   - ('Assess_loan_risk', 'Appraise_property')
#   - ('Assess_loan_risk', 'Assess_eligibility')
#   - ('Check_credit_history', 'Appraise_property')
#   - ('Check_credit_history', 'Assess_loan_risk')
#
# #### New and Deleted Transitions ####
# - **New transitions added to the process:** None
# - **Deleted transitions from the process:**
#   - ('Assess_loan_risk', 'Appraise_property')
#   - ('Appraise_property', 'Assess_eligibility')
#
# #### Activities and Transitions ####
# - **All transitions in the reference window:**
#   - [('Verify_repayment_agreement', 'Cancel_application'), ('Send_acceptance_pack', 'Verify_repayment_agreement'), ('Send_home_insurance_quote', 'Verify_repayment_agreement'), ('Receive_updated_application', 'Check__application__form_completeness'), ('Assess_loan_risk', 'Assess_eligibility'), ('Check_credit_history', 'Assess_loan_risk'), ('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check__application__form_completeness', 'Return_application_back_to_applicant'), ('Loan__application_received', 'Check__application__form_completeness'), ('Check__application__form_completeness', 'Appraise_property'), ('Verify_repayment_agreement', 'Approve_application'), ('Assess_eligibility', 'Reject_application'), ('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack'), ('Check_credit_history', 'Appraise_property'), ('Assess_loan_risk', 'Appraise_property'), ('Appraise_property', 'Check_credit_history'), ('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote'), ('Reject_application', 'Loan_application_rejected'), ('Approve_application', 'Loan__application_approved'), ('Appraise_property', 'Assess_eligibility'), ('Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested'), ('Cancel_application', 'Loan__application_canceled'), ('Return_application_back_to_applicant', 'Receive_updated_application'), ('Appraise_property', 'Assess_loan_risk'), ('Check__application__form_completeness', 'Check_credit_history')]
# - **All transitions in the detection window:**
#   - [('Verify_repayment_agreement', 'Cancel_application'), ('Send_acceptance_pack', 'Verify_repayment_agreement'), ('Send_home_insurance_quote', 'Verify_repayment_agreement'), ('Receive_updated_application', 'Check__application__form_completeness'), ('Assess_loan_risk', 'Assess_eligibility'), ('Check_credit_history', 'Assess_loan_risk'), ('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check__application__form_completeness', 'Return_application_back_to_applicant'), ('Loan__application_received', 'Check__application__form_completeness'), ('Check__application__form_completeness', 'Appraise_property'), ('Verify_repayment_agreement', 'Approve_application'), ('Assess_eligibility', 'Reject_application'), ('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack'), ('Check_credit_history', 'Appraise_property'), ('Appraise_property', 'Check_credit_history'), ('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote'), ('Reject_application', 'Loan_application_rejected'), ('Approve_application', 'Loan__application_approved'), ('Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested'), ('Cancel_application', 'Loan__application_canceled'), ('Return_application_back_to_applicant', 'Receive_updated_application'), ('Appraise_property', 'Assess_loan_risk'), ('Check__application__form_completeness', 'Check_credit_history')]
#
# ### Confirming BPMN Diagram Analysis ###
#
# 1. **Change in Parallel Fragment:**
#    - **Before Drift:** The parallel fragment includes 'Appraise_property' and a nested sequential fragment '->( 'Check_credit_history', 'Assess_loan_risk' )'.
#    - **After Drift:** The parallel fragment includes 'Appraise_property' and 'Check_credit_history' as separate parallel activities. The 'Assess_loan_risk' activity has been moved out of the parallel fragment and placed sequentially after it.
#
# 2. **Change in Sequence:**
#    - **Before Drift:** 'Assess_loan_risk' is part of the nested sequential fragment within the parallel fragment.
#    - **After Drift:** 'Assess_loan_risk' is now a standalone activity that follows the parallel fragment.
#
# ### Additional Insights from Detailed Data ###
#
# #### Control-Flow Changes
# - **Transitions with variations in probability and frequency** indicate that the process flow has been altered, affecting how often certain transitions occur.
# - **Deleted transitions** such as ('Assess_loan_risk', 'Appraise_property') and ('Appraise_property', 'Assess_eligibility') confirm the restructuring of the process flow.
#
# #### Movements of Activities
# - The movement of 'Assess_loan_risk' from within the parallel fragment to a position after it is confirmed by the absence of the transition ('Assess_loan_risk', 'Appraise_property') in the detection window.
#
# #### Adjustments in Loops
# - No explicit loops are mentioned in the BPMN diagrams or detailed data, so no adjustments in loops are inferred.
#
# #### Skippability of Activities
# - No new or deleted transitions suggest changes in skippability directly. However, the restructuring of the parallel and sequential flows might indirectly affect the skippability of activities, particularly 'Assess_loan_risk', which now must be completed after both 'Appraise_property' and 'Check_credit_history'.
#
# ### Conclusion ###
#
# The BPMN diagram analysis is accurate and aligns with the detailed data provided. The primary changes involve the restructuring of the parallel fragment and the movement of 'Assess_loan_risk' to a sequential position after the parallel activities. This restructuring likely aims to ensure that risk assessment is completed only after both property appraisal and credit history checks are done independently, potentially improving the process's efficiency and reliability.
# ################################ characterization_classification #####################################
# ### Step-by-Step Analysis ###
#
# #### Step 1: Summarize the Analysis Information ####
#
# 1. **Alterations in Activities and Transitions:**
#    - **Transitions with variations in probability and frequency:**
#      - ('Appraise_property', 'Assess_eligibility')
#      - ('Appraise_property', 'Assess_loan_risk')
#      - ('Assess_loan_risk', 'Appraise_property')
#      - ('Assess_loan_risk', 'Assess_eligibility')
#      - ('Check_credit_history', 'Appraise_property')
#      - ('Check_credit_history', 'Assess_loan_risk')
#    - **New transitions added to the process:** None
#    - **Deleted transitions from the process:**
#      - ('Assess_loan_risk', 'Appraise_property')
#      - ('Appraise_property', 'Assess_eligibility')
#
# 2. **BPMN Diagrams Comparison:**
#    - **Before Drift:** 'Assess_loan_risk' is part of a nested sequential fragment within a parallel fragment.
#    - **After Drift:** 'Assess_loan_risk' is moved out of the parallel fragment and placed sequentially after it.
#
# #### Step 2: Identify the Change Pattern ####
#
# 1. **Change in Parallel Fragment:**
#    - **Before Drift:** The parallel fragment includes 'Appraise_property' and a nested sequential fragment '->( 'Check_credit_history', 'Assess_loan_risk' )'.
#    - **After Drift:** The parallel fragment includes 'Appraise_property' and 'Check_credit_history' as separate parallel activities. The 'Assess_loan_risk' activity has been moved out of the parallel fragment and placed sequentially after it.
#
# 2. **Change in Sequence:**
#    - **Before Drift:** 'Assess_loan_risk' is part of the nested sequential fragment within the parallel fragment.
#    - **After Drift:** 'Assess_loan_risk' is now a standalone activity that follows the parallel fragment.
#
# #### Step 3: Match with Pre-defined Change Patterns ####
#
# - **Parallel Move (PM):**
#   - **Evidence:**
#     - Parallel (+) fragment changed in BPMN diagram comparison.
#     - Both new and deleted transitions in the list of variations involving the moved activity ('Assess_loan_risk') involved in the change pattern.
#     - Activity ('Assess_loan_risk') moved elsewhere in BPMN diagram and connected with other activities.
#
# #### Step 4: Conclusion ####
#
# Based on the analysis, the most significant change pattern identified is a **Parallel Move (PM)** involving the activity **'Assess_loan_risk'**.
#
# ### Final Result ###
#
# ```python
# ### result_dict = {'concept_drift' : ['Yes'], 'change_pattern' : ['PM'], 'activities' : ['Assess_loan_risk']}
# ```
# ################################ characterization_classification_dict #####################################
# {'concept_drift': ['Yes'], 'change_pattern': ['PM'], 'activities': ['Assess_loan_risk']}
# Validation metrics
# Adding informations
# step 1
# step 2
# step 3
# step 4
# step 6a
# step 6b
# ################################ llm_bpmn_analysis_response #####################################
# ### Analysis of BPMN Diagrams Before and After Concept Drift ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             'Send_acceptance_pack',
#             'Send_home_insurance_quote',
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Identified Changes ###
#
# 1. **Control-Flow Changes:**
#    - **Conditional Fragment Changes:**
#      - **Before Drift:** The conditional fragment `X` within the sequence `->( 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', X( 'Send_acceptance_pack', 'Send_home_insurance_quote' ), 'Verify_repayment_agreement', X( ->( 'Cancel_application', 'Loan__application_canceled' ), ->( 'Approve_application', 'Loan__application_approved' ) ) )` indicates that either `Send_acceptance_pack` or `Send_home_insurance_quote` is executed.
#      - **After Drift:** The conditional fragment `X` within the sequence `->( 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack', 'Send_home_insurance_quote', 'Verify_repayment_agreement', X( ->( 'Cancel_application', 'Loan__application_canceled' ), ->( 'Approve_application', 'Loan__application_approved' ) ) )` indicates that both `Send_acceptance_pack` and `Send_home_insurance_quote` are executed sequentially.
#
# 2. **Activity Movement:**
#    - The activities `Send_acceptance_pack` and `Send_home_insurance_quote` have moved from being conditionally executed (one or the other) to being sequentially executed (both are executed in order).
#
# 3. **Loops and Silent Transitions:**
#    - There are no changes in loops (`*`) or silent transitions (`tau`) between the two diagrams.
#
# ### Summary of Changes ###
# - The primary change observed is in the conditional fragment handling the acceptance pack and home insurance quote. Initially, either `Send_acceptance_pack` or `Send_home_insurance_quote` was executed based on a condition. After the concept drift, both activities are executed sequentially without any conditional check.
# - This change indicates a shift in the business process where both acceptance pack and home insurance quote are now mandatory steps in the process, rather than being conditionally executed.
#
# By identifying these changes, we can infer that the business process has become more stringent in ensuring that both acceptance pack and home insurance quote are always sent, possibly to improve customer service or compliance with new regulations.
# ################################ llm_transition_analysis_response #####################################
# ### Confirming BPMN Diagram Analysis with Detailed Data ###
#
# #### Control-Flow Changes ####
# The BPMN diagram analysis identified a significant change in the control-flow, particularly in the handling of the acceptance pack and home insurance quote. Initially, either `Send_acceptance_pack` or `Send_home_insurance_quote` was executed based on a condition. After the concept drift, both activities are executed sequentially.
#
# **Detailed Data Confirmation:**
# - **New transitions added to the process:** `('Send_acceptance_pack', 'Send_home_insurance_quote')`
# - **Deleted transitions from the process:** `('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')`, `('Send_acceptance_pack', 'Verify_repayment_agreement')`
#
# The detailed data confirms the BPMN analysis. The new transition `('Send_acceptance_pack', 'Send_home_insurance_quote')` indicates that after sending the acceptance pack, the process now proceeds to send the home insurance quote. The deleted transition `('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')` confirms that the conditional execution of `Send_home_insurance_quote` has been removed.
#
# #### Activity Movement ####
# The activities `Send_acceptance_pack` and `Send_home_insurance_quote` have moved from being conditionally executed to being sequentially executed.
#
# **Detailed Data Confirmation:**
# - **Transitions with variations in probability and frequency:** `('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack')`, `('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')`, `('Send_acceptance_pack', 'Verify_repayment_agreement')`, `('Send_acceptance_pack', 'Send_home_insurance_quote')`, `('Send_home_insurance_quote', 'Verify_repayment_agreement')`
#
# The variations in transitions' probability and frequency further support the movement of activities. The new transition `('Send_acceptance_pack', 'Send_home_insurance_quote')` and the deletion of `('Send_acceptance_pack', 'Verify_repayment_agreement')` indicate that the process flow has been altered to ensure both activities are executed sequentially.
#
# #### Loops and Silent Transitions ####
# The BPMN analysis indicated no changes in loops or silent transitions.
#
# **Detailed Data Confirmation:**
# - **All transitions in the reference and detection windows:** No new loops (`*`) or silent transitions (`tau`) are present in the detailed data.
#
# This confirms the BPMN analysis that there are no changes in loops or silent transitions.
#
# #### Skippability of Activities ####
# The BPMN analysis did not explicitly address skippability changes. However, the detailed data can provide insights into this aspect.
#
# **Detailed Data Confirmation:**
# - **Deleted transitions from the process:** `('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')`
# - **New transitions added to the process:** `('Send_acceptance_pack', 'Send_home_insurance_quote')`
#
# The deletion of the transition `('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')` and the addition of `('Send_acceptance_pack', 'Send_home_insurance_quote')` indicate that `Send_home_insurance_quote` is no longer skippable. Previously, it was conditionally executed based on `Check_if_home_insurance_quote_is_requested`. Now, it is always executed after `Send_acceptance_pack`.
#
# ### Summary of Detailed Data Confirmation ###
# - **Control-Flow Changes:** Confirmed. The transition from conditional to sequential execution of `Send_acceptance_pack` and `Send_home_insurance_quote` is validated by the new and deleted transitions.
# - **Activity Movement:** Confirmed. The movement of activities from conditional to sequential execution is supported by variations in transition probabilities and frequencies.
# - **Loops and Silent Transitions:** Confirmed. No changes in loops or silent transitions are observed.
# - **Skippability of Activities:** Confirmed. The detailed data indicates that `Send_home_insurance_quote` is no longer skippable, aligning with the BPMN analysis.
#
# ### Conclusion ###
# The detailed data corroborates the initial BPMN diagram analysis, confirming the identified changes in control-flow, activity movement, and skippability of activities. The business process has indeed become more stringent, ensuring that both the acceptance pack and home insurance quote are always sent, likely to improve customer service or comply with new regulations.
# ################################ characterization_classification #####################################
# ### Step-by-Step Analysis ###
#
# #### Step 1: Confirm Concept Drift ####
# Based on the provided analysis, it is clear that there is a significant change in the business process. The transition from conditional to sequential execution of `Send_acceptance_pack` and `Send_home_insurance_quote` indicates a concept drift.
#
# #### Step 2: Identify the Change Pattern ####
# Given the detailed analysis and the BPMN diagrams comparison, we need to classify the change pattern. Let's evaluate the change patterns:
#
# 1. **Control-Flow Changes:**
#    - The conditional fragment `X` has been altered to a sequential execution.
#    - This aligns with the **CF (Conflict)** pattern, where two connected activities change from a conditional (X) fragment to sequential execution.
#
# 2. **Activity Movement:**
#    - The activities `Send_acceptance_pack` and `Send_home_insurance_quote` have moved from being conditionally executed to being sequentially executed.
#    - This further supports the **CF (Conflict)** pattern.
#
# 3. **Skippability of Activities:**
#    - The activity `Send_home_insurance_quote` is no longer skippable, aligning with the **CB (Conditional Branch)** pattern.
#    - However, the primary change is the shift from conditional to sequential execution, which is more indicative of the **CF (Conflict)** pattern.
#
# #### Step 3: Identify Involved Activities ####
# The activities involved in the change pattern are `Send_acceptance_pack` and `Send_home_insurance_quote`.
#
# ### Final Conclusion ###
# Based on the analysis, the most significant change pattern is **CF (Conflict)**, involving the activities `Send_acceptance_pack` and `Send_home_insurance_quote`.
#
# ### result_dict ###
# ```python
# result_dict = {'concept_drift' : ['Yes'], 'change_pattern' : ['CF'], 'activities' : ['Send_acceptance_pack', 'Send_home_insurance_quote']}
# ```
# ################################ characterization_classification_dict #####################################
# {'concept_drift': ['Yes'], 'change_pattern': ['CF'], 'activities': ['Send_acceptance_pack', 'Send_home_insurance_quote']}
# Validation metrics
# Adding informations
# step 1
# step 2
# step 3
# step 4
# step 6a
# step 6b
# ################################ llm_bpmn_analysis_response #####################################
# ### Analysis of BPMN Diagrams Before and After Concept Drift ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote',
#                 'Prepare_acceptance_pack'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Key Differences and Analysis ###
#
# 1. **Change in Sequence of Activities:**
#    - **Before Drift:** The sequence within the conditional fragment starts with 'Prepare_acceptance_pack' followed by 'Check_if_home_insurance_quote_is_requested'.
#    - **After Drift:** The sequence within the conditional fragment starts with 'Check_if_home_insurance_quote_is_requested' followed by 'Prepare_acceptance_pack'.
#
# 2. **Change in Conditional Fragment:**
#    - **Before Drift:** The conditional fragment 'X' within the sequence 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested' contains:
#      - 'Send_acceptance_pack'
#      - 'Send_home_insurance_quote'
#    - **After Drift:** The conditional fragment 'X' within the sequence 'Check_if_home_insurance_quote_is_requested' contains:
#      - 'Send_acceptance_pack'
#      - 'Send_home_insurance_quote'
#      - 'Prepare_acceptance_pack'
#
# 3. **Activity Movement:**
#    - The activity 'Prepare_acceptance_pack' has moved from being outside the inner conditional fragment to being inside it.
#
# ### Summary of Concept Drift ###
# - **Structural Changes:** The primary structural change is the reordering of activities within the conditional fragment. The activity 'Prepare_acceptance_pack' has been moved inside the conditional fragment that checks if a home insurance quote is requested.
# - **Control-Flow Changes:** The control flow has been altered by changing the sequence of activities and the nesting of the conditional fragment.
# - **Impact on Process:** These changes could impact the process by altering the order in which certain checks and preparations are made, potentially affecting the efficiency and outcome of the loan application process.
#
# By identifying these changes, we can better understand how the process has evolved and what implications these modifications might have on the overall business process.
# ################################ llm_transition_analysis_response #####################################
# ### Confirming BPMN Diagram Analysis with Detailed Data ###
#
# #### Key Differences and Analysis Confirmation ####
#
# 1. **Change in Sequence of Activities:**
#    - **Before Drift:** The sequence within the conditional fragment starts with 'Prepare_acceptance_pack' followed by 'Check_if_home_insurance_quote_is_requested'.
#    - **After Drift:** The sequence within the conditional fragment starts with 'Check_if_home_insurance_quote_is_requested' followed by 'Prepare_acceptance_pack'.
#
#    **Confirmation:**
#    - The detailed data shows new transitions such as ('Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack') and deleted transitions like ('Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested'). This confirms the change in sequence.
#
# 2. **Change in Conditional Fragment:**
#    - **Before Drift:** The conditional fragment 'X' within the sequence 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested' contains:
#      - 'Send_acceptance_pack'
#      - 'Send_home_insurance_quote'
#    - **After Drift:** The conditional fragment 'X' within the sequence 'Check_if_home_insurance_quote_is_requested' contains:
#      - 'Send_acceptance_pack'
#      - 'Send_home_insurance_quote'
#      - 'Prepare_acceptance_pack'
#
#    **Confirmation:**
#    - The detailed data indicates new transitions such as ('Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack') and ('Prepare_acceptance_pack', 'Verify_repayment_agreement'). This confirms the inclusion of 'Prepare_acceptance_pack' within the conditional fragment.
#
# 3. **Activity Movement:**
#    - The activity 'Prepare_acceptance_pack' has moved from being outside the inner conditional fragment to being inside it.
#
#    **Confirmation:**
#    - The detailed data supports this movement with the new transition ('Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack') and the deletion of ('Assess_eligibility', 'Prepare_acceptance_pack').
#
# ### Additional Insights from Detailed Data ###
#
# 1. **Changes in Control-Flow:**
#    - **New Transitions:**
#      - ('Check_if_home_insurance_quote_is_requested', 'Prepare_acceptance_pack')
#      - ('Prepare_acceptance_pack', 'Verify_repayment_agreement')
#      - ('Assess_eligibility', 'Check_if_home_insurance_quote_is_requested')
#    - **Deleted Transitions:**
#      - ('Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested')
#      - ('Assess_eligibility', 'Prepare_acceptance_pack')
#
#    These changes indicate a reordering and restructuring of the control flow, particularly around the 'Prepare_acceptance_pack' activity.
#
# 2. **Movements of Activities:**
#    - The movement of 'Prepare_acceptance_pack' is confirmed by the new and deleted transitions mentioned above.
#
# 3. **Adjustments in Loops:**
#    - There are no explicit loops mentioned in the BPMN diagrams or the detailed data. However, the reordering of activities and transitions could imply changes in implicit loops or repeated sequences.
#
# 4. **Skippability of Activities:**
#    - The transition ('Assess_eligibility', 'Check_if_home_insurance_quote_is_requested') suggests that 'Prepare_acceptance_pack' can now be skipped if 'Check_if_home_insurance_quote_is_requested' is not required. This was not explicitly captured in the BPMN diagrams but is inferred from the detailed data.
#
# ### Summary of Concept Drift ###
#
# - **Structural Changes:** The primary structural change is the reordering of activities within the conditional fragment. The activity 'Prepare_acceptance_pack' has been moved inside the conditional fragment that checks if a home insurance quote is requested.
# - **Control-Flow Changes:** The control flow has been altered by changing the sequence of activities and the nesting of the conditional fragment.
# ...
# ################################ characterization_classification #####################################
# ### Step-by-Step Analysis ###
#
# #### Step 1: Identify Concept Drift ####
# Based on the provided analysis, there is a clear indication of a change in the business process. The activity 'Verify_repayment_agreement' has been replaced by 'Replaced_Activity'. This replacement is consistent across both the BPMN diagrams and the detailed data analysis.
#
# #### Step 2: Determine the Change Pattern ####
# Given the nature of the change, we need to classify it according to the predefined change patterns:
#
# - **SRE (Serial Remove/Add):** This pattern involves adding or removing an activity in a sequence. However, the replacement here does not fit this pattern as the sequence structure remains unchanged.
# - **PRE (Parallel Remove/Add):** This pattern involves adding or removing an activity in a parallel fragment. The change does not fit this pattern as there are no changes in the parallel fragments.
# - **CRE (Conditional Remove/Add):** This pattern involves adding or removing an activity in a conditional fragment. The change does not fit this pattern as there are no changes in the conditional fragments.
# - **RP (Replace):** This pattern involves replacing an activity with another in the exact same position. The change fits this pattern perfectly as 'Verify_repayment_agreement' is replaced by 'Replaced_Activity' without altering the control-flow structure.
#
# #### Step 3: Identify Involved Activities ####
# The activities involved in the change are:
# - **Deleted Activity:** 'Verify_repayment_agreement'
# - **New Activity:** 'Replaced_Activity'
#
# ### Final Conclusion ###
# Based on the analysis, the concept drift is present, and the most significant change pattern is the replacement (RP) of the activity 'Verify_repayment_agreement' with 'Replaced_Activity'.
#
# ### result_dict = {'concept_drift' : ['Yes'], 'change_pattern' : ['RP'], 'activities' : ['Verify_repayment_agreement', 'Replaced_Activity']}
# ################################ characterization_classification_dict #####################################
# {'concept_drift': ['Yes'], 'change_pattern': ['RP'], 'activities': ['Verify_repayment_agreement', 'Replaced_Activity']}
# Validation metrics
# Adding informations
# step 1
# step 2
# step 3
# step 4
# step 6a
# step 6b
# ################################ llm_bpmn_analysis_response #####################################
# ### Analysis of BPMN Diagrams Before and After Concept Drift ###
#
# #### BPMN Before Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Verify_repayment_agreement',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# #### BPMN After Concept Drift ####
# ```
# ->(
#     'Loan__application_received',
#     *(
#         'Check__application__form_completeness',
#         ->(
#             'Return_application_back_to_applicant',
#             'Receive_updated_application'
#         )
#     ),
#     +(
#         'Appraise_property',
#         ->(
#             'Check_credit_history',
#             'Assess_loan_risk'
#         )
#     ),
#     'Assess_eligibility',
#     X(
#         ->(
#             'Verify_repayment_agreement',
#             X(
#                 'Send_acceptance_pack',
#                 'Send_home_insurance_quote'
#             ),
#             'Prepare_acceptance_pack',
#             'Check_if_home_insurance_quote_is_requested',
#             X(
#                 ->(
#                     'Cancel_application',
#                     'Loan__application_canceled'
#                 ),
#                 ->(
#                     'Approve_application',
#                     'Loan__application_approved'
#                 )
#             )
#         ),
#         ->(
#             'Reject_application',
#             'Loan_application_rejected'
#         )
#     )
# )
# ```
#
# ### Key Differences and Analysis ###
#
# 1. **Order of Activities in Conditional Fragment:**
#    - **Before Drift:**
#      - The sequence within the conditional fragment is:
#        - 'Prepare_acceptance_pack'
#        - 'Check_if_home_insurance_quote_is_requested'
#        - Nested conditional fragment:
#          - 'Send_acceptance_pack'
#          - 'Send_home_insurance_quote'
#        - 'Verify_repayment_agreement'
#        - Nested conditional fragment:
#          - 'Cancel_application'
#          - 'Loan__application_canceled'
#          - 'Approve_application'
#          - 'Loan__application_approved'
#    - **After Drift:**
#      - The sequence within the conditional fragment is:
#        - 'Verify_repayment_agreement'
#        - Nested conditional fragment:
#          - 'Send_acceptance_pack'
#          - 'Send_home_insurance_quote'
#        - 'Prepare_acceptance_pack'
#        - 'Check_if_home_insurance_quote_is_requested'
#        - Nested conditional fragment:
#          - 'Cancel_application'
#          - 'Loan__application_canceled'
#          - 'Approve_application'
#          - 'Loan__application_approved'
#
# 2. **Movement of 'Verify_repayment_agreement':**
#    - **Before Drift:** 'Verify_repayment_agreement' is placed after 'Check_if_home_insurance_quote_is_requested' and the nested conditional fragment.
#    - **After Drift:** 'Verify_repayment_agreement' is moved to the beginning of the sequence within the conditional fragment.
#
# 3. **Movement of 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested':**
#    - **Before Drift:** These activities are placed at the beginning of the sequence within the conditional fragment.
#    - **After Drift:** These activities are moved after 'Verify_repayment_agreement' and the nested conditional fragment.
#
# ### Summary of Changes ###
# - The primary change observed is the reordering of activities within the conditional fragment after the 'Assess_eligibility' activity.
# - 'Verify_repayment_agreement' is now the first activity in the sequence within the conditional fragment.
# - 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have been moved to follow 'Verify_repayment_agreement' and the nested conditional fragment.
#
# These changes indicate a shift in the process flow, potentially reflecting a new business rule or priority in verifying repayment agreements earlier in the process. This reordering could impact the overall efficiency and outcome of the loan application process.
# ################################ llm_transition_analysis_response #####################################
# ### Confirming BPMN Diagram Analysis with Detailed Data ###
#
# #### Key Differences and Analysis Confirmation ####
#
# 1. **Order of Activities in Conditional Fragment:**
#    - **Before Drift:**
#      - The sequence within the conditional fragment is:
#        - 'Prepare_acceptance_pack'
#        - 'Check_if_home_insurance_quote_is_requested'
#        - Nested conditional fragment:
#          - 'Send_acceptance_pack'
#          - 'Send_home_insurance_quote'
#        - 'Verify_repayment_agreement'
#        - Nested conditional fragment:
#          - 'Cancel_application'
#          - 'Loan__application_canceled'
#          - 'Approve_application'
#          - 'Loan__application_approved'
#    - **After Drift:**
#      - The sequence within the conditional fragment is:
#        - 'Verify_repayment_agreement'
#        - Nested conditional fragment:
#          - 'Send_acceptance_pack'
#          - 'Send_home_insurance_quote'
#        - 'Prepare_acceptance_pack'
#        - 'Check_if_home_insurance_quote_is_requested'
#        - Nested conditional fragment:
#          - 'Cancel_application'
#          - 'Loan__application_canceled'
#          - 'Approve_application'
#          - 'Loan__application_approved'
#
# 2. **Movement of 'Verify_repayment_agreement':**
#    - **Before Drift:** 'Verify_repayment_agreement' is placed after 'Check_if_home_insurance_quote_is_requested' and the nested conditional fragment.
#    - **After Drift:** 'Verify_repayment_agreement' is moved to the beginning of the sequence within the conditional fragment.
#
# 3. **Movement of 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested':**
#    - **Before Drift:** These activities are placed at the beginning of the sequence within the conditional fragment.
#    - **After Drift:** These activities are moved after 'Verify_repayment_agreement' and the nested conditional fragment.
#
# ### Detailed Data Analysis ###
#
# #### Transitions with Variations in Probability and Frequency:
# - The transitions with variations in probability and frequency confirm the reordering of activities within the conditional fragment:
#   - Transitions such as ('Assess_eligibility', 'Prepare_acceptance_pack') and ('Assess_eligibility', 'Verify_repayment_agreement') indicate the shift in the sequence.
#   - The presence of new transitions like ('Verify_repayment_agreement', 'Send_acceptance_pack') and ('Verify_repayment_agreement', 'Send_home_insurance_quote') further supports the reordering.
#
# #### New and Deleted Transitions:
# - **New Transitions:**
#   - ('Verify_repayment_agreement', 'Send_acceptance_pack')
#   - ('Send_acceptance_pack', 'Prepare_acceptance_pack')
#   - ('Send_home_insurance_quote', 'Prepare_acceptance_pack')
#   - ('Check_if_home_insurance_quote_is_requested', 'Approve_application')
#   - ('Check_if_home_insurance_quote_is_requested', 'Cancel_application')
#   - ('Verify_repayment_agreement', 'Send_home_insurance_quote')
#   - ('Assess_eligibility', 'Verify_repayment_agreement')
# - **Deleted Transitions:**
#   - ('Verify_repayment_agreement', 'Cancel_application')
#   - ('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote')
#   - ('Assess_eligibility', 'Prepare_acceptance_pack')
#   - ('Send_acceptance_pack', 'Verify_repayment_agreement')
#   - ('Verify_repayment_agreement', 'Approve_application')
#   - ('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack')
#   - ('Send_home_insurance_quote', 'Verify_repayment_agreement')
#
# These new and deleted transitions align with the observed changes in the BPMN diagrams, confirming the reordering of activities.
#
# ### Additional Insights and Nuances ###
#
# #### Changes in Control-Flow:
# - The reordering of activities within the conditional fragment indicates a change in the control-flow, prioritizing 'Verify_repayment_agreement' earlier in the process.
#
# #### Movements of Activities:
# - The movement of 'Verify_repayment_agreement' to the beginning of the sequence within the conditional fragment is a significant change.
# - 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have been moved to follow 'Verify_repayment_agreement' and the nested conditional fragment.
#
# #### Adjustments in Loops:
# - There are no explicit loops in the provided BPMN diagrams, so no adjustments in loops are inferred from the process flow data.
#
# #### Skippability of Activities:
# - The new transitions ('Verify_repayment_agreement', 'Send_acceptance_pack') and ('Verify_repayment_agreement', 'Send_home_insurance_quote') suggest that 'Send_acceptance_pack' and 'Send_home_insurance_quote' can now be skipped if 'Verify_repayment_agreement' leads directly to 'Prepare_acceptance_pack' or 'Check_if_home_insurance_quote_is_requested'.
# - The deleted transitions ('Verify_repayment_agreement', 'Cancel_application') and ('Verify_repayment_agreement', 'Approve_application') indicate that 'Cancel_application' and 'Approve_application' are no longer directly reachable from 'Verify_repayment_agreement', affecting their skippability.
#
# ### Summary of Changes ###
# - The primary change observed is the reordering of activities within the conditional fragment after the 'Assess_eligibility' activity.
# - 'Verify_repayment_agreement' is now the first activity in the sequence within the conditional fragment.
# - 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have been moved to follow 'Verify_repayment_agreement' and the nested conditional fragment.
# - New transitions have been added, and some transitions have been deleted, affecting the skippability of certain activities.
#
# These changes indicate a shift in the process flow, potentially reflecting a new business rule or priority in verifying repayment agreements earlier in the process. This reordering could impact the overall efficiency and outcome of the loan application process.
# ################################ characterization_classification #####################################
# ### Step-by-Step Analysis ###
#
# #### Step 1: Confirm Concept Drift ####
# Based on the provided analysis, there is a clear indication of changes in the process flow, particularly the reordering of activities within the conditional fragment. This confirms the presence of concept drift.
#
# #### Step 2: Identify the Most Significant Change Pattern ####
# Given the detailed analysis, the most significant change pattern can be identified by examining the evidence and matching it with the predefined change patterns.
#
# 1. **Order of Activities in Conditional Fragment:**
#    - The sequence of activities within the conditional fragment has changed.
#    - 'Verify_repayment_agreement' has moved to the beginning of the sequence.
#    - 'Prepare_acceptance_pack' and 'Check_if_home_insurance_quote_is_requested' have moved to follow 'Verify_repayment_agreement' and the nested conditional fragment.
#
# 2. **New and Deleted Transitions:**
#    - New transitions such as ('Verify_repayment_agreement', 'Send_acceptance_pack') and ('Verify_repayment_agreement', 'Send_home_insurance_quote') indicate the reordering.
#    - Deleted transitions such as ('Verify_repayment_agreement', 'Cancel_application') and ('Check_if_home_insurance_quote_is_requested', 'Send_home_insurance_quote') further support the reordering.
#
# 3. **Change Pattern Classification:**
#    - The reordering of activities within the conditional fragment suggests a **Conditional Move (CM)** pattern.
#    - Evidence:
#      - Conditional (X) fragment changed in BPMN diagram comparison.
#      - Both new and deleted transitions in the list of variations involving the moved activities ('Verify_repayment_agreement', 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested').
#
# #### Step 3: Identify Involved Activities ####
# The activities involved in the most significant change pattern (CM) are:
# - 'Verify_repayment_agreement'
# - 'Prepare_acceptance_pack'
# - 'Check_if_home_insurance_quote_is_requested'
#
# ### Final Conclusion ###
# Based on the analysis, the final conclusion is as follows:
#
# ```python
# ### result_dict = {'concept_drift' : ['Yes'], 'change_pattern' : ['CM'], 'activities' : ['Verify_repayment_agreement', 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested']}
# ```
# ################################ characterization_classification_dict #####################################
# {'concept_drift': ['Yes'], 'change_pattern': ['CM'], 'activities': ['Verify_repayment_agreement', 'Prepare_acceptance_pack', 'Check_if_home_insurance_quote_is_requested']}
# Validation metrics
# Adding informations

# %%
TMPD_logs_results_experiment_df
# Out:
#     localization_activities_precision  localization_activities_recall  \
# 0                              0.2632                          1.0000
# 1                              0.2105                          1.0000
# 2                              0.2105                          1.0000
# 3                              0.3158                          1.0000
# 4                              0.2632                          1.0000
# 5                              0.2105                          1.0000
# 6                              0.3000                          1.0000
# 7                              0.2632                          1.0000
# 8                              0.3158                          1.0000
# 9                              0.2632                          1.0000
# 10                             0.3000                          1.0000
# 11                             0.4211                          1.0000
#
#     localization_activities_f1_score  characterization_concept_drift_match  \
# 0                             0.4167                                1.0000
# 1                             0.3478                                1.0000
# 2                             0.3478                                1.0000
# 3                             0.4800                                1.0000
# 4                             0.4167                                1.0000
# 5                             0.3478                                1.0000
# 6                             0.4615                                1.0000
# 7                             0.4167                                1.0000
# 8                             0.4800                                1.0000
# 9                             0.4167                                1.0000
# 10                            0.4615                                1.0000
# 11                            0.5926                                1.0000
#
#     characterization_change_pattern_match_f1_score  \
# 0                                           1.0000
# 1                                           0.0000
# 2                                           1.0000
# 3                                           1.0000
# 4                                           1.0000
# 5                                           1.0000
# 6                                           0.0000
# 7                                           1.0000
# 8                                           1.0000
# 9                                           1.0000
# 10                                          1.0000
# 11                                          0.0000
#
#     characterization_change_pattern_match_precision  \
# 0                                            1.0000
# 1                                            0.0000
# 2                                            1.0000
# 3                                            1.0000
# 4                                            1.0000
# 5                                            1.0000
# 6                                            0.0000
# 7                                            1.0000
# 8                                            1.0000
# 9                                            1.0000
# 10                                           1.0000
# 11                                           0.0000
#
#     characterization_change_pattern_match_recall  \
# 0                                         1.0000
# 1                                         0.0000
# 2                                         1.0000
# 3                                         1.0000
# 4                                         1.0000
# 5                                         1.0000
# 6                                         0.0000
# 7                                         1.0000
# 8                                         1.0000
# 9                                         1.0000
# 10                                        1.0000
# 11                                        0.0000
#
#     characterization_activities_precision  characterization_activities_recall  \
# 0                                  1.0000                              1.0000
# 1                                  1.0000                              0.3333
# 2                                  1.0000                              1.0000
# 3                                  1.0000                              1.0000
# 4                                  0.2222                              1.0000
# 5                                  1.0000                              1.0000
# 6                                  1.0000                              1.0000
# 7                                  1.0000                              1.0000
# 8                                  1.0000                              1.0000
# 9                                  0.5000                              1.0000
# 10                                 1.0000                              1.0000
# 11                                 1.0000                              1.0000
#
#     characterization_activities_f1_score  \
# 0                                 1.0000
# 1                                 0.5000
# 2                                 1.0000
# 3                                 1.0000
# 4                                 0.3636
# 5                                 1.0000
# 6                                 1.0000
# 7                                 1.0000
# 8                                 1.0000
# 9                                 0.6667
# 10                                1.0000
# 11                                1.0000
#
#                                                                                                                                   localization_activities  \
# 0   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 1   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 2   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 3   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 4   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 5   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 6   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, START, Assess_eligibility, Send...
# 7   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 8   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 9   Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
# 10  Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Replaced_Activity, Approve_application, Assess_eligi...
# 11  Loan__application_received, Assess_loan_risk, Verify_repayment_agreement, Cancel_application, Approve_application, Assess_eligibility, Send_accept...
#
#    characterization_change_pattern  \
# 0                               CB
# 1                               PM
# 2                               CF
# 3                               CM
# 4                               CP
# 5                               FR
# 6                               CB
# 7                               PL
# 8                               PM
# 9                              SRE
# 10                              RP
# 11                              CM
#
#                                                                                                                               characterization_activities  \
# 0                                                                                     Prepare_acceptance_pack, Check_if_home_insurance_quote_is_requested
# 1                                                                                                                                        Assess_loan_risk
# 2                                                                                                         Send_acceptance_pack, Send_home_insurance_quote
# 3                                                                                                                                 Prepare_acceptance_pack
# 4   Assess_eligibility, Send_acceptance_pack, Send_home_insurance_quote, Assess_loan_risk, Verify_repayment_agreement, Check_if_home_insurance_quote_i...
# 5                                                             Check_if_home_insurance_quote_is_requested, Send_acceptance_pack, Send_home_insurance_quote
# 6                                                                           Assess_eligibility, Appraise_property, Assess_loan_risk, Check_credit_history
# 7                                                                                               Appraise_property, Check_credit_history, Assess_loan_risk
# 8                                                                                                      Prepare_acceptance_pack, Send_home_insurance_quote
# 9                                                                                                                    Assess_loan_risk, Assess_eligibility
# 10                                                                                                          Verify_repayment_agreement, Replaced_Activity
# 11                                                        Verify_repayment_agreement, Prepare_acceptance_pack, Check_if_home_insurance_quote_is_requested
#
#                                                                                                                                      localization_changes  \
# 0   {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check_if_home_insurance_quote_is_requested', ...
# 1   {'Transitions with variations in probability': [('Appraise_property', 'Assess_eligibility'), ('Appraise_property', 'Assess_loan_risk'), ('Assess_l...
# 2   {'Transitions with variations in probability': [('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack'), ('Check_if_home_insurance_...
# 3   {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check_if_home_insurance_quote_is_requested', ...
# 4   {'Transitions with variations in probability': [('Assess_loan_risk', 'Appraise_property'), ('Assess_loan_risk', 'Assess_eligibility'), ('Check_cre...
# 5   {'Transitions with variations in probability': [('Check_if_home_insurance_quote_is_requested', 'Send_acceptance_pack'), ('Check_if_home_insurance_...
# 6   {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Assess_eligibility', 'Reject_application'), (...
# 7   {'Transitions with variations in probability': [('Appraise_property', 'Assess_eligibility'), ('Appraise_property', 'Assess_loan_risk'), ('Appraise...
# 8   {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check_if_home_insurance_quote_is_requested', ...
# 9   {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Assess_eligibility', 'Reject_application'), (...
# 10  {'Transitions with variations in probability': [('Send_acceptance_pack', 'Verify_repayment_agreement'), ('Send_home_insurance_quote', 'Verify_repa...
# 11  {'Transitions with variations in probability': [('Assess_eligibility', 'Prepare_acceptance_pack'), ('Check_if_home_insurance_quote_is_requested', ...
#
#                                                                                                                                       reference_bpmn_text  \
# 0   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 1   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 2   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 3   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 4   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 5   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 6   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 7   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 8   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 9   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 10  ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 11  ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
#
#                                                                                                                                       detection_bpmn_text  \
# 0   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 1   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 2   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 3   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 4   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 5   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 6   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 7   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 8   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 9   ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 10  ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
# 11  ->( 'Loan__application_received', *( 'Check__application__form_completeness', ->( 'Return_application_back_to_applicant', 'Receive_updated_applica...
#
#                                                                                                                              change_patterns_llm_response  \
# 0   ### Step-by-Step Analysis ###\n\n#### Step 1: Confirm Concept Drift ####\nBased on the provided analysis, there is a clear indication of a structu...
# 1   ### Step-by-Step Analysis ###\n\n#### Step 1: Summarize the Analysis Information ####\n\n1. **Alterations in Activities and Transitions:**\n   - *...
# 2   ### Step-by-Step Analysis ###\n\n#### Step 1: Confirm Concept Drift ####\nBased on the provided analysis, it is clear that there is a significant ...
# 3   ### Step-by-Step Analysis ###\n\n#### Step 1: Confirm Concept Drift ####\nBased on the provided analysis, there are clear indications of changes i...
# 4   ### Step-by-Step Analysis ###\n\n#### Step 1: Identify Concept Drift ####\nBased on the provided analysis, there are significant changes in the BP...
# 5   ### Step-by-Step Analysis ###\n\n#### Step 1: Summarize the Analysis Information ####\n- **Alterations in Activities and Transitions**:\n  - No st...
# 6   ### Step-by-Step Analysis ###\n\n#### Step 1: Confirm Concept Drift ####\nBased on the provided analysis, there is a clear indication of a concept...
# 7   ### Step-by-Step Analysis ###\n\n#### Step 1: Identify Concept Drift ####\nBased on the provided analysis, there is a clear indication of a change...
# 8   ### Step-by-Step Analysis ###\n\n#### Step 1: Confirming Identified Changes ####\n\n**Sequence of Activities:**\n- **Before Drift:** 'Prepare_acce...
# 9   ### Step-by-Step Analysis ###\n\n#### Step 1: Combine All Information Previously Analyzed ####\n\n1. **Alterations in Activities and Transitions:*...
# 10  ### Step-by-Step Analysis ###\n\n#### Step 1: Identify Concept Drift ####\nBased on the provided analysis, there is a clear indication of a change...
# 11  ### Step-by-Step Analysis ###\n\n#### Step 1: Confirm Concept Drift ####\nBased on the provided analysis, there is a clear indication of changes i...
#
#                                                                           log_path  \
# 0   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cb\cb10k.mxml
# 1   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cd\cd10k.mxml
# 2   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cf\cf10k.mxml
# 3   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cm\cm10k.mxml
# 4   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\cp\cp10k.mxml
# 5   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\fr\fr10k.MXML
# 6   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\lp\lp10k.mxml
# 7   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\pl\pl10k.mxml
# 8   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\pm\pm10k.mxml
# 9   ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\re\re10k.mxml
# 10  ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\rp\rp10k.mxml
# 11  ../Input/Synthetic/Business Process Drift (Maaradji - Fast)/logs\sw\sw10k.mxml
#
#    change_pattern  log_size window_size_mode  window_size window_ref_mode  \
# 0              cb     10000            Fixed         4000           Fixed
# 1              cd     10000            Fixed         4000           Fixed
# 2              cf     10000            Fixed         4000           Fixed
# 3              cm     10000            Fixed         4000           Fixed
# 4              cp     10000            Fixed         4000           Fixed
# 5              fr     10000            Fixed         4000           Fixed
# 6              lp     10000            Fixed         4000           Fixed
# 7              pl     10000            Fixed         4000           Fixed
# 8              pm     10000            Fixed         4000           Fixed
# 9              re     10000            Fixed         4000           Fixed
# 10             rp     10000            Fixed         4000           Fixed
# 11             sw     10000            Fixed         4000           Fixed
#
#     overlap  sliding_step  reference_window_index  detection_window_index  \
# 0      True           200                       0                      75
# 1      True           200                       0                      75
# 2      True           200                       0                      75
# 3      True           200                       0                      75
# 4      True           200                       0                      75
# 5      True           200                       0                      75
# 6      True           200                       0                      75
# 7      True           200                       0                      75
# 8      True           200                       0                      75
# 9      True           200                       0                      75
# 10     True           200                       0                      75
# 11     True           200                       0                      75
#
#     pvalue_threshold  effect_prop_threshold  effect_count_threshold  \
# 0             0.0500                 0.2000                  0.0200
# 1             0.0500                 0.2000                  0.0200
# 2             0.0500                 0.2000                  0.0200
# 3             0.0500                 0.2000                  0.0200
# 4             0.0500                 0.2000                  0.0200
# 5             0.0500                 0.2000                  0.0200
# 6             0.0500                 0.2000                  0.0200
# 7             0.0500                 0.2000                  0.0200
# 8             0.0500                 0.2000                  0.0200
# 9             0.0500                 0.2000                  0.0200
# 10            0.0500                 0.2000                  0.0200
# 11            0.0500                 0.2000                  0.0200
#
#     pseudo_count llm_company llm_model  \
# 0              5      openai    gpt-4o
# 1              5      openai    gpt-4o
# 2              5      openai    gpt-4o
# 3              5      openai    gpt-4o
# 4              5      openai    gpt-4o
# 5              5      openai    gpt-4o
# 6              5      openai    gpt-4o
# 7              5      openai    gpt-4o
# 8              5      openai    gpt-4o
# 9              5      openai    gpt-4o
# 10             5      openai    gpt-4o
# 11             5      openai    gpt-4o
#
#                              llm_instructions_path  change_patterns_separated
# 0   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 1   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 2   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 3   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 4   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 5   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 6   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 7   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 8   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 9   ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 10  ../Codes/LLM_Instructions/instructions_v7.yaml                      False
# 11  ../Codes/LLM_Instructions/instructions_v7.yaml                      False

# %%
TMPD_logs_results_experiment_df['characterization_change_pattern_match_f1_score'].mean()
# Out:
# 0.75

# %%
TMPD_logs_results_experiment_df.to_excel('Results/Business_Process_Drift_Maaradji_Fast_Understanding_Task_Single_v7.xlsx')

# %%
# with PdfPages('Results/gtest_frequency3_experiment_Business_Process_Drift.pdf') as pdf:
#     for index, result in TMPD_logs_results_experiment_df.iterrows(): 
#         fig, ax = plt.subplots(figsize=(15,3))
#         plt.axis('off')
#         ax.imshow(result['display'])
#         pdf.savefig(bbox_inches='tight')
#         plt.show()
